# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Credit Card Dataset.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import StandardScaler

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
class ss(BaseEstimator, TransformerMixin):
  def fit(self, X, y=None):
    return self
  def transform(self,X):
    imputer = SimpleImputer(strategy="mean")
    X["MINIMU_PAYMENTS"]=imputer.fit_transform(X[["MINIMUM_PAYMENTS"]])
    return X

class fs(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    def transform(self,X):

          imputer = SimpleImputer(strategy="mean")
          columns_to_scale = ['BALANCE', 'PURCHASES', 'ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES','INSTALLMENTS_PURCHASES','PAYMENTS','MINIMUM_PAYMENTS']
          scaler = StandardScaler()
          X[columns_to_scale] = scaler.fit_transform(X[columns_to_scale])
          return X

# %%
from sklearn.pipeline import Pipeline

# %%
fs
# Out:
# __main__.fs

# %%
pipe = Pipeline([
    ("ss",ss()),
    ("ds",fs())
])

# %%
pipe.fit_transform(df)
# Out:
#      CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001 -0.731989           0.818182  -0.424900         -0.356934
# 1     C10002  0.786961           0.909091  -0.469552         -0.356934
# 2     C10003  0.447135           1.000000  -0.107668          0.108889
# 3     C10004  0.049099           0.636364   0.232058          0.546189
# 4     C10005 -0.358775           1.000000  -0.462063         -0.347294
# ...      ...       ...                ...        ...               ...
# 8945  C19186 -0.737950           1.000000  -0.333293         -0.356934
# 8946  C19187 -0.742423           1.000000  -0.329136         -0.356934
# 8947  C19188 -0.740398           0.833333  -0.401965         -0.356934
# 8948  C19189 -0.745174           0.833333  -0.469552         -0.356934
# 8949  C19190 -0.572575           0.666667   0.042146          0.301732
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...
